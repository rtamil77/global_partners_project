# %%
# %sql
select * from global_partner_project.bronze.date_dim

# %%
# %sql
select * from global_partner_project.gold.fact_order

# %%
# %sql
select count(*) from global_partner_project.gold.fact_order
