# %%
config_rules_order_items = {
    'app_name': {
        'target_type':'string',
        'required':True
    },
    'restaurant_id': {
        'target_type':'string',
        'required':False
    },
    'creation_time_utc': {
        'target_type':'datetime',
        'required':True,
        'format':'%Y-%m-%D'
    },
    'order_id': {
        'target_type':'string',
        'required':True
    },
    'user_id': {
        'target_type':'string',
        'required':False
    },
    'printed_card_number': {
        'target_type':'string',
        'required':False
    },
    'is_loyalty': {
        'target_type':'boolean',
        'required':True
    },
    'currency': {
        'target_type':'string',
        'required':False
    },
    'lineitem_id': {
        'target_type':'string',
        'required':True
    },
    'item_category': {
        'target_type':'string',
        'required':False
    },
    'item_name': {
        'target_type':'string',
        'required':False
    },
    'item_price': {
        'target_type':'double',
        'required':True
    },
    'item_quantity': {
        'target_type':'int',
        'required':True
    }
}
