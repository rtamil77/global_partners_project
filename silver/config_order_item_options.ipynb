# %%
config_rules_order_item_options = {
    'order_id': {
        'target_type':'string',
        'required':True
    },
    'lineitem_id': {
        'target_type':'string',
        'required':True
    },
    'option_group_name': {
        'target_type':'string',
        'required':False
    },
    'option_name': {
        'target_type':'string',
        'required':False
    },
    'option_price': {
        'target_type':'double',
        'required':True
    },
    'option_quantity': {
        'target_type':'int',
        'required':True
    }
}
