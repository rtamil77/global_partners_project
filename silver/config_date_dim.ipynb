# %%
config_rules_date_dim = {

    'date_key' : {
        'target_type':'string',
        'required':True
    },
    'year' : {
        'target_type':'int',
        'required':True
    },
    'month' : {
        'target_type':'int',
        'required':True
    },
    'week' : {
        'target_type':'int',
        'required':True
    },
    'day_of_week' : {
        'target_type':'string',
        'required':True
    },
    'is_weekend' : {
        'target_type':'boolean',
        'required':True
    },
    'is_holiday' : {
        'target_type':'boolean',
        'required':False
    },
    'holiday_name' : {
        'target_type':'string',
        'required':False
    }
}
